# %%
##DB Connection test

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (7.5 kB)
# Downloading mysql_connector_python-9.5.0-cp312-cp312-macosx_14_0_arm64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
#Configuration
db_config = {
    "host": "localhost",
    "user": "python_user",
    "password": "harshada",
    "database": "security_analytics"
}

# %%
#connection test
import mysql.connector

conn = None

try:
    conn = mysql.connector.connect(**db_config)
    if conn.is_connected():
        print("✅ Connected Successfully to MySQL database")
        cursor = conn.cursor()
        cursor.execute("SHOW TABLES;")
        tables = cursor.fetchall()
        print("\n📋 Tables found:")
        for (table,) in tables:
            print(f" - {table}")

except mysql.connector.Error as err:
    print("❌ Database connection failed:", err)

finally:
    if conn and conn.is_connected():
        conn.close()
        print("\n🔒 Connection Closed.")
# Out:
# ✅ Connected Successfully to MySQL database
#
# 📋 Tables found:
#  - departments
#  - firewall_logs
#  - login_events
#  - users
#  - vpn_logs
#  - vulnerabilities
#
# 🔒 Connection Closed.

# %%
pip install --upgrade mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /opt/anaconda3/lib/python3.12/site-packages (9.5.0)
# Note: you may need to restart the kernel to use updated packages.
